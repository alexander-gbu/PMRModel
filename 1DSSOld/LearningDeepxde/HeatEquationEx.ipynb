# %% [markdown]
# One worry: how are we going to keep track of changes as we go across? like temp and stuff. But that would just be a system of PDEs

# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt
#choses backend pytorch here if it hasnt already
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
a = 0.4
L = 1
n = 1
t_max = 1

geom = dde.geometry.Interval(0, L)
timedomain = dde.geometry.TimeDomain(0, t_max)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, i=0, j=1)
    dy_xx = dde.grad.hessian(y, x, i=0, j=0)
    return dy_t - a * dy_xx

def boundary_val_l(x):
    return 1 #sets value of T = 1

def boundary_l(x, on_boundary):
    return on_boundary and dde.utils.isclose(x[0],0) #x[0] is the x axis and after the comma is the position, x[1] is the y-axis if ur working in 2D

def boundary_flux_r(x):
    return 0 #sets dy/dx = 0

def boundary_r(x, on_boundary):
    return on_boundary and dde.utils.isclose(x[0],L) #because now were at L we need to put L there

def boundary_in(x, on_initial):
    return on_initial and dde.utils.isclose(x[1],0) #i guess here t is x's 2nd index (so 1)

def func_zeros(x):
    return np.zeros((len(x),1))

# %%
bc_l = dde.DirichletBC(geomtime, boundary_val_l, boundary_l) #might have to change to dde.icbc. ...
bc_r = dde.NeumannBC(geomtime, boundary_flux_r, boundary_r)
ic = dde.IC(geomtime, func_zeros, boundary_in)

data = dde.data.TimePDE(geomtime, pde, [bc_l, bc_r, ic], num_domain=2540, num_boundary=80, num_initial=160, num_test=2540)
#The number 2540 is the number of training residual points sampled inside the domain, and the number 80 is the number of training points sampled on the boundary. We also include 160 initial residual points for the initial conditions.
net = dde.nn.FNN([2] + [20] * 3 + [1], "tanh", "Glorot normal")
model = dde.Model(data, net)
model.compile("adam", lr=1e-3)
losshistory, train_state = model.train(iterations=20000)
#up to this point is the last example. Now if we want to make it more accurate we use the following code
model.compile("L-BFGS-B")
losshistory, train_state = model.train()
dde.saveplot(losshistory, train_state, issave=False, isplot=True)
# Out:
# Warning: 2540 points required, but 2550 points sampled.
# Compiling model...
# 'compile' took 1.362535 s
#
# Training model...
#
# Step      Train loss                                  Test loss                                   Test metric
# 0         [3.36e-02, 1.19e+00, 2.39e-02, 1.32e-02]    [3.15e-02, 1.19e+00, 2.39e-02, 1.32e-02]    []
# 1000      [4.48e-03, 1.84e-02, 5.42e-04, 1.59e-02]    [2.91e-03, 1.84e-02, 5.42e-04, 1.59e-02]    []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       8 model = dde.Model(data, net)
#       9 model.compile("adam", lr=1e-3)
# ---> 10 losshistory, train_state = model.train(iterations=20000)
#      11 #up to this point is the last example. Now if we want to make it more accurate we use the following code
#      12 model.compile("L-BFGS-B")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\utils\internal.py:22, in timing.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(f)
#      20 def wrapper(*args, **kwargs):
#      21     ts = timeit.default_timer()
# ---> 22     result = f(*args, **kwargs)
#      23     te = timeit.default_timer()
#      24     verbose = kwargs.get('verbose', 1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:690, in Model.train(self, iterations, batch_size, display_every, disregard_previous_best, callbacks, model_restore_path, model_save_path, epochs, verbose)
#     688     if iterations is None:
#     689         raise ValueError("No iterations for {}.".format(self.opt_name))
# --> 690     self._train_sgd(iterations, display_every, verbose=verbose)
#     691 self.callbacks.on_train_end()
#     693 if verbose > 0 and config.rank == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:708, in Model._train_sgd(self, iterations, display_every, verbose)
#     703 self.callbacks.on_batch_begin()
#     705 self.train_state.set_data_train(
#     706     *self.data.train_next_batch(self.batch_size)
#     707 )
# --> 708 self._train_step(
#     709     self.train_state.X_train,
#     710     self.train_state.y_train,
#     711     self.train_state.train_aux_vars,
#     712 )
#     714 self.train_state.epoch += 1
#     715 self.train_state.step += 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:595, in Model._train_step(self, inputs, targets, auxiliary_vars)
#     593     self.train_step(inputs, targets, auxiliary_vars)
#     594 elif backend_name == "pytorch":
# --> 595     self.train_step(inputs, targets, auxiliary_vars)
#     596 elif backend_name == "jax":
#     597     # TODO: auxiliary_vars
#     598     self.params, self.opt_state = self.train_step(
#     599         self.params, self.opt_state, inputs, targets
#     600     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:377, in Model._compile_pytorch.<locals>.train_step(inputs, targets, auxiliary_vars)
#     374     total_loss.backward()
#     375     return total_loss
# --> 377 self.opt.step(closure)
#     378 if self.lr_scheduler is not None:
#     379     self.lr_scheduler.step()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\optim\optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\optim\adam.py:223, in Adam.step(self, closure)
#     221 if closure is not None:
#     222     with torch.enable_grad():
# --> 223         loss = closure()
#     225 for group in self.param_groups:
#     226     params_with_grad: List[Tensor] = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:371, in Model._compile_pytorch.<locals>.train_step.<locals>.closure()
#     370 def closure():
# --> 371     losses = outputs_losses_train(inputs, targets, auxiliary_vars)[1]
#     372     total_loss = torch.sum(losses)
#     373     self.opt.zero_grad()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:325, in Model._compile_pytorch.<locals>.outputs_losses_train(inputs, targets, auxiliary_vars)
#     324 def outputs_losses_train(inputs, targets, auxiliary_vars):
# --> 325     return outputs_losses(
#     326         True, inputs, targets, auxiliary_vars, self.data.losses_train
#     327     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\model.py:313, in Model._compile_pytorch.<locals>.outputs_losses(training, inputs, targets, auxiliary_vars, losses_fn)
#     311 # if forward-mode AD is used, then a forward call needs to be passed
#     312 aux = [self.net] if config.autodiff == "forward" else None
# --> 313 losses = losses_fn(targets, outputs_, loss_fn, inputs, self, aux=aux)
#     314 if not isinstance(losses, list):
#     315     losses = [losses]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\data\data.py:13, in Data.losses_train(self, targets, outputs, loss_fn, inputs, model, aux)
#      11 def losses_train(self, targets, outputs, loss_fn, inputs, model, aux=None):
#      12     """Return a list of losses for training dataset, i.e., constraints."""
# ---> 13     return self.losses(targets, outputs, loss_fn, inputs, model, aux=aux)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\data\pde.py:149, in PDE.losses(self, targets, outputs, loss_fn, inputs, model, aux)
#     147 if self.pde is not None:
#     148     if get_num_args(self.pde) == 2:
# --> 149         f = self.pde(inputs, outputs_pde)
#     150     elif get_num_args(self.pde) == 3:
#     151         if self.auxiliary_var_fn is not None:
#
# Cell In[3], line 11, in pde(x, y)
#      10 def pde(x, y):
# ---> 11     dy_t = dde.grad.jacobian(y, x, i=0, j=1)
#      12     dy_xx = dde.grad.hessian(y, x, i=0, j=0)
#      13     return dy_t - a * dy_xx
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\gradients\gradients.py:34, in jacobian(ys, xs, i, j)
#      11 """Compute `Jacobian matrix <https://en.wikipedia.org/wiki/Jacobian_matrix_and_determinant>`_
#      12 J as J[i, j] = dy_i / dx_j, where i = 0, ..., dim_y - 1 and j = 0, ..., dim_x - 1.
#      13
#    (...)
#      31     (`i`, `j`)th entry J[`i`, `j`], `i`th row J[`i`, :], or `j`th column J[:, `j`].
#      32 """
#      33 if config.autodiff == "reverse":
# ---> 34     return gradients_reverse.jacobian(ys, xs, i=i, j=j)
#      35 if config.autodiff == "forward":
#      36     return gradients_forward.jacobian(ys, xs, i=i, j=j)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\gradients\gradients_reverse.py:73, in jacobian(ys, xs, i, j)
#      72 def jacobian(ys, xs, i=None, j=None):
# ---> 73     return jacobian._Jacobians(ys, xs, i=i, j=j)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\gradients\jacobian.py:128, in Jacobians.__call__(self, ys, xs, i, j)
#     126 if key not in self.Js:
#     127     self.Js[key] = self.JacobianClass(ys, xs)
# --> 128 return self.Js[key](i, j)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deepxde\gradients\gradients_reverse.py:29, in JacobianReverse.__call__(self, i, j)
#      26 elif backend_name == "pytorch":
#      27     # TODO: retain_graph=True has memory leak?
#      28     y = self.ys[:, i : i + 1] if self.dim_y > 1 else self.ys
# ---> 29     self.J[i] = torch.autograd.grad(
#      30         y, self.xs, grad_outputs=torch.ones_like(y), create_graph=True
#      31     )[0]
#      32 elif backend_name == "jax":
#      33     # Here, we use jax.grad to compute the gradient of a function. This is
#      34     # different from TensorFlow and PyTorch that the input of a function is
#    (...)
#      41     # the full Jacobian matrix efficiently, if needed. Another option is
#      42     # jax.vjp + jax.vmap.
#      43     grad_fn = jax.grad(lambda x: self.ys[1](x)[i])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\__init__.py:496, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     492     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     493         grad_outputs_
#     494     )
#     495 else:
# --> 496     result = _engine_run_backward(
#     497         outputs,
#     498         grad_outputs_,
#     499         retain_graph,
#     500         create_graph,
#     501         inputs,
#     502         allow_unused,
#     503         accumulate_grad=False,
#     504     )
#     505 if materialize_grads:
#     506     if any(
#     507         result[i] is None and not is_tensor_like(inputs[i])
#     508         for i in range(len(inputs))
#     509     ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
t = np.linspace(0, t_max, 100)
x = np.linspace(0, L, 200)
xx, tt = np.meshgrid(x, t) #since the two are different lengths we have to make this grid
X = np.vstack((xx.ravel(), tt.ravel())).T #here we are stacking them together. We are basically making a list of points (x, t) 100*200 of them because we can only feed one point to the model

y_pred = (model.predict(X)).reshape(len(t), len(x))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xx, tt, y_pred)
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('T')
# Out:
# Text(0.5, 0, 'T')

# %%
plt.contourf(xx, tt, y_pred, levels = 50)
plt.colorbar(label='T')
plt.xlabel('x')
plt.ylabel('t')
# Out:
# Text(0, 0.5, 't')
